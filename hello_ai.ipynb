# %% [markdown]
# <a href="https://colab.research.google.com/github/roopeshchinnakampalli/hello-ai/blob/main/hello_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello, AI!')
